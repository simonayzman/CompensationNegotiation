# %% [markdown]
# ## Compensation Data Cleaning

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import seaborn as sns

pd.set_option('display.max_rows', 100)
plt.rcParams["figure.figsize"] = (20,10)
plt.rcParams["font.weight"] = "bold"
plt.style.use('ggplot')

# %%
pd.read_json('data/raw_comp_data.json').to_csv('data/raw_comp_data.csv')
comp_raw = pd.read_csv('data/raw_comp_data.csv', index_col="rowNumber")
comp_raw.dtypes
comp_raw
# Out:
# Unnamed: 0                   int64
# timestamp                   object
# company                     object
# level                       object
# title                       object
# totalyearlycompensation    float64
# location                    object
# yearsofexperience          float64
# yearsatcompany             float64
# tag                         object
# basesalary                 float64
# stockgrantvalue            float64
# bonus                      float64
# gender                      object
# otherdetails                object
# cityid                     float64
# dmaid                      float64
# dtype: object
#            Unnamed: 0            timestamp    company  \
# rowNumber
# 1                   0  2017-06-07 11:33:27     Oracle
# 2                   1  2017-06-10 17:11:29       eBay
# 3                   2  2017-06-11 14:53:57     Amazon
# 4                   3  2017-06-13 05:35:36       Uber
# 5                   4  2017-06-14 21:22:25  Microsoft
# ...               ...                  ...        ...
# 30139           24748  2020-06-05 08:52:54    Twitter
# 30140           24749  2020-06-05 09:19:09  Bloomberg
# 30142           24750  2020-06-05 09:53:21     Google
# 30143           24751  2020-06-05 09:58:40   Broadcom
# 30144           24752  2020-06-05 10:07:11  Postmates
#
#                               level                         title  \
# rowNumber
# 1                                L3               Product Manager
# 2                              SE 2             Software Engineer
# 3                                L7               Product Manager
# 4                            Senior             Software Engineer
# 5                                64  Software Engineering Manager
# ...                             ...                           ...
# 30139                    Senior SWE             Software Engineer
# 30140      Senior Software Engineer             Software Engineer
# 30142                            L4             Software Engineer
# 30143                         ICB 3             Software Engineer
# 30144               Product Manager               Product Manager
#
#            totalyearlycompensation                    location  \
# rowNumber
# 1                            127.0            Redwood City, CA
# 2                            100.0           San Francisco, CA
# 3                            310.0                 Seattle, WA
# 4                            578.0           San Francisco, CA
# 5                            200.0                 Redmond, WA
# ...                            ...                         ...
# 30139                        370.0                New York, NY
# 30140                        212.0                New York, NY
# 30142                        185.0  London, EN, United Kingdom
# 30143                        180.0        Tel Aviv, TA, Israel
# 30144                        142.0           San Francisco, CA
#
#            yearsofexperience  yearsatcompany                             tag  \
# rowNumber
# 1                        1.5             1.5                             NaN
# 2                        5.0             3.0                             NaN
# 3                        8.0             0.0                             NaN
# 4                       10.0             2.0                             NaN
# 5                        9.0             9.0                             NaN
# ...                      ...             ...                             ...
# 30139                   10.0             6.0                             iOS
# 30140                    2.0             0.0  Distributed Systems (Back-End)
# 30142                    4.0             2.0      API Development (Back-End)
# 30143                    7.0             7.0                      Networking
# 30144                    1.0             0.0                         Android
#
#            basesalary  stockgrantvalue    bonus gender  \
# rowNumber
# 1               107.0             20.0     10.0    NaN
# 2                 NaN              NaN      NaN    NaN
# 3               155.0              NaN      NaN    NaN
# 4            180000.0        1550000.0   9000.0    NaN
# 5            169000.0         100000.0  30000.0    NaN
# ...               ...              ...      ...    ...
# 30139           187.0            150.0     33.0   Male
# 30140           177.0              0.0     35.0   Male
# 30142            98.0             57.0     30.0   Male
# 30143           110.0             55.0     15.0   Male
# 30144           130.0             12.0      0.0   Male
#
#                                otherdetails   cityid  dmaid
# rowNumber
# 1                                       NaN   7392.0  807.0
# 2                                       NaN   7419.0  807.0
# 3                                       NaN  11527.0  819.0
# 4          Stock based on $48.65 per share.   7419.0  807.0
# 5                                       NaN  11521.0  819.0
# ...                                     ...      ...    ...
# 30139                                   NaN  10182.0  501.0
# 30140                           25k signing  10182.0  501.0
# 30142                                   NaN  12008.0    0.0
# 30143                                   NaN  15900.0    0.0
# 30144                                   NaN   7419.0  807.0
#
# [24753 rows x 17 columns]

# %%
comp_renamed = comp_raw.rename(columns={
    "totalyearlycompensation": "raw_total_comp",
    "basesalary": "raw_salary",
    "stockgrantvalue": "raw_stock",
    "bonus": "raw_bonus",
    "yearsofexperience": "years_experience",
    "yearsatcompany": "years_company",
})
comp_renamed = pd.concat([
    comp_renamed.raw_total_comp,
    comp_renamed.raw_salary,
    comp_renamed.raw_stock,
    comp_renamed.raw_bonus,
    comp_renamed.drop(columns=['raw_total_comp', 'raw_salary', 'raw_stock', 'raw_bonus'])
], axis=1)
comp_renamed = comp_renamed.drop(columns=['cityid', 'dmaid', 'Unnamed: 0'])
comp_renamed.index.rename("entry_id", inplace=True)
comp_renamed
# Out:
#           raw_total_comp  raw_salary  raw_stock  raw_bonus  \
# entry_id
# 1                  127.0       107.0       20.0       10.0
# 2                  100.0         NaN        NaN        NaN
# 3                  310.0       155.0        NaN        NaN
# 4                  578.0    180000.0  1550000.0     9000.0
# 5                  200.0    169000.0   100000.0    30000.0
# ...                  ...         ...        ...        ...
# 30139              370.0       187.0      150.0       33.0
# 30140              212.0       177.0        0.0       35.0
# 30142              185.0        98.0       57.0       30.0
# 30143              180.0       110.0       55.0       15.0
# 30144              142.0       130.0       12.0        0.0
#
#                     timestamp    company                     level  \
# entry_id
# 1         2017-06-07 11:33:27     Oracle                        L3
# 2         2017-06-10 17:11:29       eBay                      SE 2
# 3         2017-06-11 14:53:57     Amazon                        L7
# 4         2017-06-13 05:35:36       Uber                    Senior
# 5         2017-06-14 21:22:25  Microsoft                        64
# ...                       ...        ...                       ...
# 30139     2020-06-05 08:52:54    Twitter                Senior SWE
# 30140     2020-06-05 09:19:09  Bloomberg  Senior Software Engineer
# 30142     2020-06-05 09:53:21     Google                        L4
# 30143     2020-06-05 09:58:40   Broadcom                     ICB 3
# 30144     2020-06-05 10:07:11  Postmates           Product Manager
#
#                                  title                    location  \
# entry_id
# 1                      Product Manager            Redwood City, CA
# 2                    Software Engineer           San Francisco, CA
# 3                      Product Manager                 Seattle, WA
# 4                    Software Engineer           San Francisco, CA
# 5         Software Engineering Manager                 Redmond, WA
# ...                                ...                         ...
# 30139                Software Engineer                New York, NY
# 30140                Software Engineer                New York, NY
# 30142                Software Engineer  London, EN, United Kingdom
# 30143                Software Engineer        Tel Aviv, TA, Israel
# 30144                  Product Manager           San Francisco, CA
#
#           years_experience  years_company                             tag  \
# entry_id
# 1                      1.5            1.5                             NaN
# 2                      5.0            3.0                             NaN
# 3                      8.0            0.0                             NaN
# 4                     10.0            2.0                             NaN
# 5                      9.0            9.0                             NaN
# ...                    ...            ...                             ...
# 30139                 10.0            6.0                             iOS
# 30140                  2.0            0.0  Distributed Systems (Back-End)
# 30142                  4.0            2.0      API Development (Back-End)
# 30143                  7.0            7.0                      Networking
# 30144                  1.0            0.0                         Android
#
#          gender                      otherdetails
# entry_id
# 1           NaN                               NaN
# 2           NaN                               NaN
# 3           NaN                               NaN
# 4           NaN  Stock based on $48.65 per share.
# 5           NaN                               NaN
# ...         ...                               ...
# 30139      Male                               NaN
# 30140      Male                       25k signing
# 30142      Male                               NaN
# 30143      Male                               NaN
# 30144      Male                               NaN
#
# [24753 rows x 14 columns]

# %%
comp_swe = comp_renamed[comp_renamed['title'] == 'Software Engineer'] # Filters for non-SWE roles
comp_swe = comp_swe.dropna(subset=['raw_salary'])
comp_swe = comp_swe.fillna(value={'raw_stock': 0, 'raw_bonus': 0})
comp_swe
# Out:
#           raw_total_comp  raw_salary  raw_stock  raw_bonus  \
# entry_id
# 4                  578.0    180000.0  1550000.0     9000.0
# 6                  173.0    120000.0        0.0    53000.0
# 8                  270.0       160.0        0.0        0.0
# 10                 190.0    110000.0    80000.0        0.0
# 13                 156.0       135.0        8.0       13.0
# ...                  ...         ...        ...        ...
# 30133              115.0       115.0        0.0        0.0
# 30139              370.0       187.0      150.0       33.0
# 30140              212.0       177.0        0.0       35.0
# 30142              185.0        98.0       57.0       30.0
# 30143              180.0       110.0       55.0       15.0
#
#                     timestamp    company                     level  \
# entry_id
# 4         2017-06-13 05:35:36       Uber                    Senior
# 6         2017-06-16 10:44:01     Amazon                        L5
# 8         2017-06-18 23:37:21   Facebook                        E4
# 10        2017-06-20 18:49:59     Amazon                        L5
# 13        2017-06-22 13:55:26  Microsoft                        62
# ...                       ...        ...                       ...
# 30133     2020-06-05 04:13:25        IBM         Advisory Engineer
# 30139     2020-06-05 08:52:54    Twitter                Senior SWE
# 30140     2020-06-05 09:19:09  Bloomberg  Senior Software Engineer
# 30142     2020-06-05 09:53:21     Google                        L4
# 30143     2020-06-05 09:58:40   Broadcom                     ICB 3
#
#                       title                    location  years_experience  \
# entry_id
# 4         Software Engineer           San Francisco, CA              10.0
# 6         Software Engineer       Vancouver, BC, Canada              11.0
# 8         Software Engineer              Menlo Park, CA               3.5
# 10        Software Engineer                 Seattle, WA               3.0
# 13        Software Engineer                 Seattle, WA               4.0
# ...                     ...                         ...               ...
# 30133     Software Engineer                 Madison, WI               6.0
# 30139     Software Engineer                New York, NY              10.0
# 30140     Software Engineer                New York, NY               2.0
# 30142     Software Engineer  London, EN, United Kingdom               4.0
# 30143     Software Engineer        Tel Aviv, TA, Israel               7.0
#
#           years_company                             tag gender  \
# entry_id
# 4                   2.0                             NaN    NaN
# 6                   1.0                             NaN    NaN
# 8                   2.0                             NaN    NaN
# 10                  3.0                             NaN    NaN
# 13                  4.0                             NaN    NaN
# ...                 ...                             ...    ...
# 30133               1.0  Distributed Systems (Back-End)   Male
# 30139               6.0                             iOS   Male
# 30140               0.0  Distributed Systems (Back-End)   Male
# 30142               2.0      API Development (Back-End)   Male
# 30143               7.0                      Networking   Male
#
#                               otherdetails
# entry_id
# 4         Stock based on $48.65 per share.
# 6                                      NaN
# 8                                      NaN
# 10                                     NaN
# 13                                     NaN
# ...                                    ...
# 30133                              Masters
# 30139                                  NaN
# 30140                          25k signing
# 30142                                  NaN
# 30143                                  NaN
#
# [14808 rows x 14 columns]

# %% [markdown]
# ### Scale Target Values to 1000's

# %%
# OUTPUT IMPLICATIONS
# Total comp is already scaled down to 1000's number
# Maximum total comp is $2.5m
comp_swe[comp_swe.raw_total_comp > 999].sort_values(by='raw_total_comp', ascending=False)
# Out:
#           raw_total_comp  raw_salary  raw_stock  raw_bonus  \
# entry_id
# 12694             2500.0       350.0     1500.0      650.0
# 21423             2400.0       500.0     1800.0      100.0
# 9041              2221.0       275.0     1867.0       79.0
# 11377             1800.0       350.0      700.0      750.0
# 28380             1800.0       300.0     1400.0      100.0
# 8202              1750.0       200.0     1200.0      350.0
# 14822             1630.0       330.0     1150.0      150.0
# 248               1500.0       300.0     1150.0       50.0
# 7029              1450.0       300.0     1085.0       65.0
# 14501             1425.0       320.0      975.0      130.0
# 10322             1400.0       280.0     1050.0       70.0
# 636               1400.0       250.0     1150.0        0.0
# 15484             1300.0       285.0      872.0      143.0
# 21884             1300.0       280.0      950.0       70.0
# 20148             1250.0       335.0      780.0      140.0
# 10043             1200.0       300.0      850.0       50.0
# 242               1120.0       252.0      790.0       78.0
# 17526             1101.0       280.0      625.0      196.0
# 3165              1070.0       286.0      649.0       64.0
# 10662             1030.0       400.0        0.0      630.0
# 20063             1010.0       280.0      665.0       65.0
# 17844             1005.0       280.0      550.0      170.0
#
#                     timestamp              company                   level  \
# entry_id
# 12694     2019-07-31 22:52:33            Microsoft                      69
# 21423     2020-01-30 15:13:18             Doordash                      E7
# 9041      2019-05-23 13:45:55             Facebook                      E7
# 11377     2019-07-02 15:05:10             Facebook                      E8
# 28380     2020-05-11 21:51:56              Google                       L8
# 8202      2019-04-27 21:44:39               Google  Distinguished Engineer
# 14822     2019-09-15 09:55:05               Google                      L8
# 248       2018-01-27 07:29:30                 Uber                      L6
# 7029      2019-03-24 20:15:29             Facebook                      E8
# 14501     2019-09-12 20:33:30                Apple      Technical Director
# 10322     2019-06-16 15:31:13             Facebook                      E7
# 636       2018-05-13 23:54:26                 Snap                      L7
# 15484     2019-09-27 20:52:00               VMware      Principal Engineer
# 21884     2020-02-06 11:09:06             Facebook                     IC7
# 20148     2020-01-13 21:16:14               Google                      L8
# 10043     2019-06-15 17:32:52                Apple              Director 1
# 242       2018-01-24 04:51:35               Google                      T7
# 17526     2019-11-13 11:53:44             Facebook                      E7
# 3165      2018-10-27 14:08:52               Google                      L7
# 10662     2019-06-18 17:00:28  Jane Street Capital       Software Engineer
# 20063     2020-01-11 20:18:16             Facebook                      E7
# 17844     2019-11-19 23:03:16             Facebook                      E7
#
#                       title           location  years_experience  \
# entry_id
# 12694     Software Engineer        Redmond, WA              11.0
# 21423     Software Engineer        Seattle, WA              20.0
# 9041      Software Engineer       New York, NY               8.0
# 11377     Software Engineer     Menlo Park, CA              31.0
# 28380     Software Engineer        Seattle, WA              15.0
# 8202      Software Engineer  Mountain View, CA              22.0
# 14822     Software Engineer  Mountain View, CA              16.0
# 248       Software Engineer  San Francisco, CA              15.0
# 7029      Software Engineer     Menlo Park, CA               7.0
# 14501     Software Engineer      Cupertino, CA              30.0
# 10322     Software Engineer     Menlo Park, CA              25.0
# 636       Software Engineer  San Francisco, CA              11.0
# 15484     Software Engineer        Atlanta, GA              22.0
# 21884     Software Engineer     Menlo Park, CA              22.0
# 20148     Software Engineer  Mountain View, CA              19.0
# 10043     Software Engineer      Cupertino, CA              35.0
# 242       Software Engineer       New York, NY              10.0
# 17526     Software Engineer     Menlo Park, CA              20.0
# 3165      Software Engineer  Mountain View, CA              27.0
# 10662     Software Engineer       New York, NY               7.0
# 20063     Software Engineer     Menlo Park, CA              15.0
# 17844     Software Engineer     Menlo Park, CA              20.0
#
#           years_company                             tag  gender  \
# entry_id
# 12694              11.0                         ML / AI  Female
# 21423               2.0                         ML / AI     NaN
# 9041                6.0                      Full Stack    Male
# 11377              11.0                        Security    Male
# 28380              10.0                         ML / AI    Male
# 8202               18.0                        Security    Male
# 14822              12.0                         ML / AI    Male
# 248                 3.0                             NaN     NaN
# 7029                5.0                         ML / AI    Male
# 14501              19.0                             iOS    Male
# 10322               5.0  Distributed Systems (Back-End)    Male
# 636                 2.0                             NaN    Male
# 15484              10.0          Mobile (iOS + Android)    Male
# 21884               8.0                             iOS    Male
# 20148               9.0                         ML / AI     NaN
# 10043              10.0  Distributed Systems (Back-End)     NaN
# 242                 7.0                             NaN     NaN
# 17526               0.5                         Android    Male
# 3165                9.0                      Networking     NaN
# 10662               4.0  Distributed Systems (Back-End)    Male
# 20063               2.0  Distributed Systems (Back-End)    Male
# 17844               0.0                         ML / AI    Male
#
#                                                otherdetails
# entry_id
# 12694                                                   NaN
# 21423                                                   NaN
# 9041                                                    NaN
# 11377                                                   NaN
# 28380                                                   PhD
# 8202                                                    NaN
# 14822                                                   NaN
# 248                                                     NaN
# 7029                                                    NaN
# 14501                                                   NaN
# 10322                                                   NaN
# 636                                                     NaN
# 15484                                                   NaN
# 21884                                                   NaN
# 20148                                       Masters and PhD
# 10043                                                   NaN
# 242                                                     NaN
# 17526                                                   NaN
# 3165      Form limits to $999k. Should be $1070k total, ...
# 10662                                                   NaN
# 20063                                               Masters
# 17844                                                   NaN

# %%
# OUTPUT IMPLICATION
# Salary needs to be scaled down for all values above 5,000
# Maximum SCALED salary is $750k from Netflix
# Entry 13778 needs to be dropped
# Entry 322 and 889 salaries need to fixed or dropped
comp_swe[comp_swe.raw_salary > 700].sort_values(by='raw_salary', ascending=False)
# Out:
#           raw_total_comp  raw_salary  raw_stock  raw_bonus  \
# entry_id
# 322                300.0   2000000.0    45000.0    55000.0
# 889                162.0   1620000.0        0.0        0.0
# 2177               630.0    600000.0       30.0        0.0
# 12194              440.0    425000.0    21000.0        0.0
# 11988              430.0    410000.0    20500.0        0.0
# ...                  ...         ...        ...        ...
# 363                145.0     12000.0     5000.0    20000.0
# 615                133.0     12000.0        0.0       13.0
# 8266               120.0     10000.0        0.0    20000.0
# 13778               75.0      7111.0        0.0      889.0
# 16438              750.0       750.0        0.0        0.0
#
#                     timestamp      company                     level  \
# entry_id
# 322       2018-02-19 19:14:29        Intel        Principal engineer
# 889       2018-06-12 05:04:06  Squarespace                  Senior I
# 2177      2018-09-20 22:40:58      Netflix  Senior Software Engineer
# 12194     2019-07-21 17:26:13      Netflix  Senior Software Engineer
# 11988     2019-07-16 21:41:33      Netflix  Senior Software Engineer
# ...                       ...          ...                       ...
# 363       2018-03-06 18:50:18       Amazon                        L4
# 615       2018-05-10 17:50:23       NetApp                   MTS III
# 8266      2019-04-30 16:09:30         USAA       Software Engineer I
# 13778     2019-08-28 00:15:04      Rakuten                         A
# 16438     2019-10-18 13:57:18      Netflix  Senior Software Engineer
#
#                       title          location  years_experience  \
# entry_id
# 322       Software Engineer     Hillsboro, OR              22.0
# 889       Software Engineer      New York, NY               7.0
# 2177      Software Engineer     Los Gatos, CA              10.0
# 12194     Software Engineer     Los Gatos, CA               7.0
# 11988     Software Engineer     Los Gatos, CA              10.0
# ...                     ...               ...               ...
# 363       Software Engineer       Seattle, WA               3.0
# 615       Software Engineer    Pittsburgh, PA               6.0
# 8266      Software Engineer       Phoenix, AZ               8.0
# 13778     Software Engineer  Tokyo, TY, Japan               7.0
# 16438     Software Engineer     Los Gatos, CA              15.0
#
#           years_company                             tag gender  \
# entry_id
# 322                20.0                             NaN    NaN
# 889                 7.0      API Development (Back-End)   Male
# 2177                1.0  Distributed Systems (Back-End)    NaN
# 12194               0.0  Distributed Systems (Back-End)   Male
# 11988               2.0  Distributed Systems (Back-End)   Male
# ...                 ...                             ...    ...
# 363                 0.6                             NaN    NaN
# 615                 3.0                             NaN   Male
# 8266                0.0      API Development (Back-End)   Male
# 13778               5.0      API Development (Back-End)   Male
# 16438               7.0                        Security   Male
#
#                                              otherdetails
# entry_id
# 322                                                   NaN
# 889       Lots of vested ISOs, some fresh RSUs, illiquid.
# 2177                                                  NaN
# 12194                                                 NaN
# 11988                                                 NaN
# ...                                                   ...
# 363                                                   NaN
# 615                                                   NaN
# 8266                                                  NaN
# 13778                                                 NaN
# 16438                          +5% into stock option plan
#
# [534 rows x 14 columns]

# %%
# OUTPUT IMPLICATION
# Stock CAN be scaled down for all values above 1,250 (See entry 444)
# Some stock inputs are inconsistent with salary or bonus scaling choice
comp_swe[(comp_swe.raw_stock > 999) & (comp_swe.raw_stock < 1e4)].sort_values(by='raw_stock', ascending=False)
# Out:
#           raw_total_comp  raw_salary  raw_stock  raw_bonus  \
# entry_id
# 1485             240.000       156.0     9720.0       77.0
# 987              130.000    118000.0     9365.0    11000.0
# 159              155.000    129000.0     9000.0    17000.0
# 654              157.056    133956.0     9000.0    14100.0
# 633              193.000    155000.0     8000.0    30000.0
# 5861             116.000       108.0     8000.0        0.0
# 712                           61  Software Engineer  Vancouver, BC, Canada
# 790                           L4  Software Engineer            Seattle, WA
# 483                           61  Software Engineer            Redmond, WA
# 44                            60  Software Engineer            Redmond, WA
# 1547                          60  Software Engineer            Redmond, WA
# 10296                         L3  Software Engineer           Portland, OR
# 1268                          L4  Software Engineer            Seattle, WA
# 1039                          G5  Software Engineer         Sacramento, CA
# 664                           L4  Software Engineer             Irvine, CA
# 626                       Senior  Software Engineer      San Francisco, CA
# 449                      Grade 6  Software Engineer          Hillsboro, OR
# 1524                          60  Software Engineer            Redmond, WA
# 355             Senior Associate  Software Engineer         Washington, DC
# 592                           L4  Software Engineer    Toronto, ON, Canada
# 9041                          E7  Software Engineer           New York, NY
# 21423                         E7  Software Engineer            Seattle, WA
# 926                           L4  Software Engineer            Seattle, WA
# 468                           L5  Software Engineer      San Francisco, CA
# 1410                         l59  Software Engineer            Redmond, WA
# 12694                         69  Software Engineer            Redmond, WA
# 28380                         L8  Software Engineer            Seattle, WA
# 1470                          E6  Software Engineer         Menlo Park, CA
# 444                          III  Software Engineer        Santa Clara, CA
# 8202      Distinguished Engineer  Software Engineer      Mountain View, CA
# 248                           L6  Software Engineer      San Francisco, CA
# 636                           L7  Software Engineer      San Francisco, CA
# 14822                         L8  Software Engineer      Mountain View, CA
# 7029                          E8  Software Engineer         Menlo Park, CA
# 10322                         E7  Software Engineer         Menlo Park, CA
# 124                           E6  Software Engineer         Menlo Park, CA
#
#           years_experience  years_company                             tag  \
# entry_id
# 1485                   2.0            0.0      API Development (Back-End)
# 987                    3.0            2.0     Web Development (Front-End)
# 159                    3.0            3.0                             NaN
# 654                    4.0            4.0                             NaN
# 633                    4.0            1.0                             NaN
# 5861                   3.0            3.0                      Full Stack
# 703                    3.0            3.0                             NaN
# 1589                   3.0            3.0                        Firmware
# 1219                   1.0            1.0                      Full Stack
# 32                     2.0            0.0                             NaN
# 1232                   1.0            1.0                      Full Stack
# 14081                 12.0            1.0                      Full Stack
# 553                    2.0            2.0                             NaN
# 1519                   3.0            0.5                            Data
# 1138                  10.0            8.0                      Full Stack
# 1495                  12.0            9.0      API Development (Back-End)
# 7579                   2.0            2.0                      Full Stack
# 335                    1.0            1.0                             NaN
# 164                   15.0            4.0                             NaN
# 1451                   4.0            4.0                             Sql
# 774                    5.0            0.0                             NaN
# 1154                   7.0            3.0                Data Engineering
# 363                    3.0            0.6                             NaN
# 740                    2.0            2.0                             NaN
# 1467                   0.0            0.0  Distributed Systems (Back-End)
# 712                    7.0            2.0                             NaN
# 790                    1.0            1.0                             NaN
# 483                    7.0            2.8                             NaN
# 44                     3.0            2.0                             NaN
# 1547                   1.0            1.0      API Development (Back-End)
# 10296                 13.0            1.0      API Development (Back-End)
# 1268                   1.0            0.0      API Development (Back-End)
# 1039                   2.0            2.0                        Firmware
# 664                    0.8            0.8                             NaN
# 626                    5.0            1.0                             NaN
# 449                    3.0            3.0                             NaN
# 1524                   2.0            2.0                      Full Stack
# 355                    2.0            2.0                             NaN
# 592                    1.0            1.0                             NaN
# 9041                   8.0            6.0                      Full Stack
# 21423                 20.0            2.0                         ML / AI
# 926                    1.0            0.0                             NaN
# 468                    6.0            3.0                             NaN
# 1410                   0.0            0.0  Distributed Systems (Back-End)
# 12694                 11.0           11.0                         ML / AI
# 28380                 15.0           10.0                         ML / AI
# 1470                  12.0            1.0                         ML / AI
# 444                    4.5            2.0                             NaN
# 8202                  22.0           18.0                        Security
# 248                   15.0            3.0                             NaN
# 636                   11.0            2.0                             NaN
# 14822                 16.0           12.0                         ML / AI
# 7029                   7.0            5.0                         ML / AI
# 10322                 25.0            5.0  Distributed Systems (Back-End)
# 124                   10.0            1.0                             NaN
#
#           gender                                       otherdetails
# entry_id
# 1485         NaN                                                NaN
# 987       Female                                                NaN
# 159          NaN                                                NaN
# 654         Male                                                NaN
# 633       Female                                                NaN
# 5861        Male                                                NaN
# 703         Male                                                NaN
# 1589         NaN                                                NaN
# 1219        Male                                                NaN
# 32           NaN                                                NaN
# 1232      Female                                                NaN
# 14081     Female                                                NaN
# 553         Male                                                NaN
# 1519         NaN                                                NaN
# 1138        Male                                                NaN
# 1495         NaN                                                NaN
# 7579      Female                                                NaN
# 335          NaN                                                NaN
# 164          NaN                                                NaN
# 1451         NaN                                                NaN
# 774         Male                                                NaN
# 1154        Male                                                NaN
# 363          NaN                                                NaN
# 740         Male                                                NaN
# 1467         NaN                                                NaN
# 712         Male  You must be in the top 3-5% of employees in Ca...
# 790         Male                                                NaN
# 483         Male  didn't count benefits (+24k) in total comp bec...
# 44           NaN                                                NaN
# 1547         NaN                                                NaN
# 10296     Female                                                NaN
# 1268        Male  65k of stocks at 5/15/40/40 vesting schedule p...
# 1039        Male                                                NaN
# 664         Male                                                NaN
# 626         Male                                                NaN
# 449          NaN                                                NaN
# 1524         NaN                                                NaN
# 355          NaN                                                NaN
# 592         Male                                                NaN
# 9041        Male                                                NaN
# 21423        NaN                                                NaN
# 926         Male                                                NaN
# 468          NaN     pre-ipo stock grant not included in total comp
# 1410         NaN                                                NaN
# 12694     Female                                                NaN
# 28380       Male                                                PhD
# 1470         NaN                                                NaN
# 444          NaN                                                NaN
# 8202        Male                                                NaN
# 248          NaN                                                NaN
# 636         Male                                                NaN
# 14822       Male                                                NaN
# 7029        Male                                                NaN
# 10322       Male                                                NaN
# 124          NaN                                                NaN

# %%
# OUTPUT IMPLICATION
# Bonus should be scaled down for all values above 999 (See entry 995)
# Some bonus inputs are inconsistent with salary or stock scaling choice
comp_swe[(comp_swe.raw_bonus > 499) & (comp_swe.raw_bonus < 1e4)].sort_values(by='raw_bonus', ascending=False)
# Out:
#           raw_total_comp  raw_salary  raw_stock  raw_bonus  \
# entry_id
# 720                129.0     95000.0    20000.0     9500.0
# 335                109.0     93420.0     6250.0     9342.0
# 1524               131.0       119.0     2700.0     9300.0
# 471                 71.0     62000.0        0.0     9300.0
# 4                  578.0    180000.0  1550000.0     9000.0
# 14272               72.0     63000.0        0.0     9000.0
# 13143               88.0     79200.0        0.0     8500.0
# 505                240.0       158.0       70.0     8500.0
# 13684        London, EN, United Kingdom               1.0            1.0
# 13760                     Littleton, MA               5.0            5.0
# 1189                  San Francisco, CA              10.0            4.0
# 1266               Yorktown Heights, NY               6.0            2.0
# 444                     Santa Clara, CA               4.5            2.0
# 6748                       San Jose, CA               6.0            5.0
# 12650                       Chicago, IL              12.0            8.0
# 1201                         Austin, TX               6.0            3.0
# 995                 Toronto, ON, Canada               1.0            1.0
# 13778                  Tokyo, TY, Japan               7.0            5.0
# 11377                    Menlo Park, CA              31.0           11.0
# 12694                       Redmond, WA              11.0           11.0
# 10662                      New York, NY               7.0            4.0
# 12829                     Princeton, NJ               5.0            1.0
#
#                                      tag  gender  \
# entry_id
# 720                                  NaN    Male
# 335                                  NaN     NaN
# 1524                          Full Stack     NaN
# 471                                  NaN     NaN
# 4                                    NaN     NaN
# 14272                         Full Stack    Male
# 13143                         Full Stack    Male
# 505                                  NaN    Male
# 1169                                 NaN    Male
# 553                                  NaN    Male
# 779                                  NaN    Male
# 117                                  NaN     NaN
# 7845          API Development (Back-End)    Male
# 965           API Development (Back-End)    Male
# 8805                             ML / AI  Female
# 9114      Distributed Systems (Back-End)    Male
# 9907          API Development (Back-End)    Male
# 875                           Full Stack    Male
# 877                           Full Stack    Male
# 40                                   NaN     NaN
# 164                                  NaN     NaN
# 6919                          Full Stack    Male
# 10794         API Development (Back-End)    Male
# 449                                  NaN     NaN
# 1039                            Firmware    Male
# 355                                  NaN     NaN
# 14047                             DevOps     NaN
# 1519                                Data     NaN
# 1495          API Development (Back-End)     NaN
# 1726                          Full Stack     NaN
# 6735          API Development (Back-End)    Male
# 1144      Distributed Systems (Back-End)    Male
# 783                                  NaN    Male
# 771                                  NaN    Male
# 488                                  NaN    Male
# 712                                  NaN    Male
# 733                                  NaN    Male
# 792       Distributed Systems (Back-End)    Male
# 1883                          Full Stack     NaN
# 227                                  NaN     NaN
# 384                                  NaN     NaN
# 778                                  NaN    Male
# 3518                          Full Stack     NaN
# 4959                      python backend    Male
# 508                                  NaN     NaN
# 13684                         Full Stack  Female
# 13760                           Security    Male
# 1189                          Full Stack    Male
# 1266                             ML / AI     NaN
# 444                                  NaN     NaN
# 6748                             ML / AI    Male
# 12650         API Development (Back-End)    Male
# 1201         Web Development (Front-End)    Male
# 995           API Development (Back-End)    Male
# 13778         API Development (Back-End)    Male
# 11377                           Security    Male
# 12694                            ML / AI  Female
# 10662     Distributed Systems (Back-End)    Male
# 12829                            ML / AI    Male
#
#                                                otherdetails
# entry_id
# 720                                                     NaN
# 335                                                     NaN
# 1524                                                    NaN
# 471                                                     NaN
# 4                          Stock based on $48.65 per share.
# 14272                                      Java, Javascript
# 13143                                                   NaN
# 505                                                     NaN
# 1169                                                    NaN
# 553                                                     NaN
# 779                                                     NaN
# 117                                                     NaN
# 7845                                                    NaN
# 965                                                     NaN
# 8805                                                    NaN
# 9114                                                    NaN
# 9907                                                    NaN
# 875                                                     NaN
# 877                                                     NaN
# 40                                                      NaN
# 164                                                     NaN
# 6919                                                    NaN
# 10794                                                   NaN
# 449                                                     NaN
# 1039                                                    NaN
# 355                                                     NaN
# 14047                                                   NaN
# 1519                                                    NaN
# 1495                                                    NaN
# 1726                                                    NaN
# 6735                                                    NaN
# 1144                                                    NaN
# 783                                                     NaN
# 771                                                     NaN
# 488       Stock grand 60k on signing + 40k after a year....
# 712       You must be in the top 3-5% of employees in Ca...
# 733                                                     NaN
# 792                                                     NaN
# 1883                                                    NaN
# 227                                                     NaN
# 384                                                     NaN
# 778                                                     NaN
# 3518                            Exchange rate of 72 is used
# 4959                                             net salary
# 508                                                     NaN
# 13684                                              Graduate
# 13760                                                   NaN
# 1189                                                    NaN
# 1266                                                    NaN
# 444                                                     NaN
# 6748                                                    NaN
# 12650                                                   NaN
# 1201                                     .8 (80%) PMR Ratio
# 995       Free mobile, Free Subway Pass, Very good resou...
# 13778                                                   NaN
# 11377                                                   NaN
# 12694                                                   NaN
# 10662                                                   NaN
# 12829                                    non-tradable stock

# %%
normalized_total_comp = comp_swe.raw_total_comp.rename('total_comp')

# %%
def comp_salary_scaler(salary):
    if salary > 5e3:
        return salary / 1e3
    return salary

normalized_salary = comp_swe.raw_salary.apply(comp_salary_scaler).rename('salary')

# %%
def comp_bonus_scaler(bonus):
    if bonus > 999:
        return bonus / 1e3
    return bonus

normalized_bonus = comp_swe.raw_bonus.apply(comp_bonus_scaler).rename('bonus')

# %%
# Check that salary/stock/bonus actually sum up to the provided total compensation +/- $20k
def comp_is_consistent(total_comp, salary, stock, bonus):
    return np.absolute(total_comp - (salary + stock + bonus)) <= 20

# Stock is most complicated to scale, with most room for input error
stocks = []
for entry in comp_swe.itertuples():
    index = entry.Index
    stock = comp_swe.raw_stock[index]
    
    total_comp = normalized_total_comp[index]
    salary = normalized_salary[index]
    bonus = normalized_bonus[index]
    
    consistent_stock = np.nan
    if comp_is_consistent(total_comp, salary, stock, bonus): # Attempts stock value as-is
        consistent_stock = stock
    elif comp_is_consistent(total_comp, salary, stock / 4.0, bonus): # Attempts stock value as vested over 4 years
        consistent_stock = stock / 4.0
    elif comp_is_consistent(total_comp, salary, stock / 1e3, bonus): # Attempts stock value scaled down to 1000's
        consistent_stock = stock / 1e3
    elif comp_is_consistent(total_comp, salary, stock / 4e3, bonus): # Attempts above two cases together
        consistent_stock = stock / 4e3
        
    stocks.append(consistent_stock)

normalized_stock = pd.Series(data=stocks, index=comp_swe.index).rename('stock')
normalized_stock
# Out:
# entry_id
# 4        387.5
# 6          0.0
# 8          NaN
# 10        80.0
# 13         8.0
#          ...
# 30133      0.0
# 30139    150.0
# 30140      0.0
# 30142     57.0
# 30143     55.0
# Name: stock, Length: 14808, dtype: float64

# %%
comp_normalized = pd.concat([
    normalized_total_comp,
    normalized_salary,
    normalized_stock,
    normalized_bonus,
    comp_swe
], axis=1)
comp_normalized = comp_normalized.drop(columns=['raw_total_comp', 'raw_salary', 'raw_stock', 'raw_bonus'])
comp_normalized = comp_normalized.dropna(subset=['stock']) # Remove "inconsistent" sum values, represented as NaN
comp_normalized
# Out:
#           total_comp  salary  stock  bonus            timestamp    company  \
# entry_id
# 4              578.0   180.0  387.5    9.0  2017-06-13 05:35:36       Uber
# 6              173.0   120.0    0.0   53.0  2017-06-16 10:44:01     Amazon
# 10             190.0   110.0   80.0    0.0  2017-06-20 18:49:59     Amazon
# 13             156.0   135.0    8.0   13.0  2017-06-22 13:55:26  Microsoft
# 16             201.0   157.0   26.0   28.0  2017-06-26 21:25:45  Microsoft
# ...              ...     ...    ...    ...                  ...        ...
# 30133          115.0   115.0    0.0    0.0  2020-06-05 04:13:25        IBM
# 30139          370.0   187.0  150.0   33.0  2020-06-05 08:52:54    Twitter
# 30140          212.0   177.0    0.0   35.0  2020-06-05 09:19:09  Bloomberg
# 30142          185.0    98.0   57.0   30.0  2020-06-05 09:53:21     Google
# 30143          180.0   110.0   55.0   15.0  2020-06-05 09:58:40   Broadcom
#
#                              level              title  \
# entry_id
# 4                           Senior  Software Engineer
# 6                               L5  Software Engineer
# 10                              L5  Software Engineer
# 13                              62  Software Engineer
# 16                              63  Software Engineer
# ...                            ...                ...
# 30133            Advisory Engineer  Software Engineer
# 30139                   Senior SWE  Software Engineer
# 30140     Senior Software Engineer  Software Engineer
# 30142                           L4  Software Engineer
# 30143                        ICB 3  Software Engineer
#
#                             location  years_experience  years_company  \
# entry_id
# 4                  San Francisco, CA              10.0            2.0
# 6              Vancouver, BC, Canada              11.0            1.0
# 10                       Seattle, WA               3.0            3.0
# 13                       Seattle, WA               4.0            4.0
# 16                       Seattle, WA              12.0            6.0
# ...                              ...               ...            ...
# 30133                    Madison, WI               6.0            1.0
# 30139                   New York, NY              10.0            6.0
# 30140                   New York, NY               2.0            0.0
# 30142     London, EN, United Kingdom               4.0            2.0
# 30143           Tel Aviv, TA, Israel               7.0            7.0
#
#                                      tag gender  \
# entry_id
# 4                                    NaN    NaN
# 6                                    NaN    NaN
# 10                                   NaN    NaN
# 13                                   NaN    NaN
# 16                                   NaN    NaN
# ...                                  ...    ...
# 30133     Distributed Systems (Back-End)   Male
# 30139                                iOS   Male
# 30140     Distributed Systems (Back-End)   Male
# 30142         API Development (Back-End)   Male
# 30143                         Networking   Male
#
#                               otherdetails
# entry_id
# 4         Stock based on $48.65 per share.
# 6                                      NaN
# 10                                     NaN
# 13                                     NaN
# 16                                     NaN
# ...                                    ...
# 30133                              Masters
# 30139                                  NaN
# 30140                          25k signing
# 30142                                  NaN
# 30143                                  NaN
#
# [14557 rows x 14 columns]

# %% [markdown]
# ### Sanity Check on Target Value Ranges

# %%
comp_normalized.salary.plot.box()
comp_normalized.sort_values(by='salary', ascending=False)
# Out:
#           total_comp  salary  stock  bonus            timestamp    company  \
# entry_id
# 16438          750.0   750.0    0.0    0.0  2019-10-18 13:57:18    Netflix
# 3486           990.0   650.0  250.0   90.0  2018-11-01 01:06:12     Google
# 2177           630.0   600.0   30.0    0.0  2018-09-20 22:40:58    Netflix
# 29811          600.0   600.0    3.0    0.0  2020-05-31 09:24:42   Netflix
# 8645           630.0   600.0   30.0    0.0  2019-05-12 13:25:58    Netflix
# ...              ...     ...    ...    ...                  ...        ...
# 18235           10.0     5.0    0.0    0.0  2019-11-28 13:47:26     Andela
# 29059           10.0     5.0    0.0    1.0  2020-05-20 17:44:06  Accenture
# 16379           10.0     5.0    0.0    0.0  2019-10-17 01:59:32     Andela
# 11191           11.0     2.0    8.0    1.0  2019-06-27 14:26:22   Flipkart
# 14967           10.0     1.0    1.0    8.0  2019-09-16 23:19:35  Microsoft
#
#                               level              title              location  \
# entry_id
# 16438      Senior Software Engineer  Software Engineer         Los Gatos, CA
# 3486                       L9 / L10  Software Engineer           Chicago, IL
# 2177       Senior Software Engineer  Software Engineer         Los Gatos, CA
# 29811                        Senior  Software Engineer         Los Gatos, CA
# 8645       Senior Software Engineer  Software Engineer         Los Gatos, CA
# ...                             ...                ...                   ...
# 18235                            E1  Software Engineer    Lagos, LA, Nigeria
# 29059     Software Engineer Analyst  Software Engineer  Bangalore, KA, India
# 16379                            E1  Software Engineer    Lagos, LA, Nigeria
# 11191           Principal Architect  Software Engineer  Bangalore, KA, India
# 14967                         SDE I  Software Engineer    Chennai, TN, India
#
#           years_experience  years_company                             tag  \
# entry_id
# 16438                 15.0            7.0                        Security
# 3486                  20.0           15.0                         ML / AI
# 2177                  10.0            1.0  Distributed Systems (Back-End)
# 29811                  9.0            4.0  Distributed Systems (Back-End)
# 8645                  12.0            3.0                      Full Stack
# ...                    ...            ...                             ...
# 18235                  5.0            1.0                      Full Stack
# 29059                  2.0            2.0     Web Development (Front-End)
# 16379                  5.0            1.0                      Full Stack
# 11191                 12.0           12.0                          DevOps
# 14967                  0.0            1.0     Web Development (Front-End)
#
#          gender                otherdetails
# entry_id
# 16438      Male  +5% into stock option plan
# 3486        NaN                         NaN
# 2177        NaN                         NaN
# 29811       NaN                         NaN
# 8645       Male                         NaN
# ...         ...                         ...
# 18235      Male                         NaN
# 29059      Male                         NaN
# 16379       NaN                         NaN
# 11191     Other                         NaN
# 14967       NaN                         NaN
#
# [14557 rows x 14 columns]

# %%
comp_normalized.stock.plot.box()
comp_normalized.sort_values(by='stock', ascending=False)
# Out:
#           total_comp  salary   stock  bonus            timestamp    company  \
# entry_id
# 9041          2221.0   275.0  1867.0   79.0  2019-05-23 13:45:55   Facebook
# 21423         2400.0   500.0  1800.0  100.0  2020-01-30 15:13:18   Doordash
# 12694         2500.0   350.0  1500.0  650.0  2019-07-31 22:52:33  Microsoft
# 28380         1800.0   300.0  1400.0  100.0  2020-05-11 21:51:56    Google
# 8202          1750.0   200.0  1200.0  350.0  2019-04-27 21:44:39     Google
# ...              ...     ...     ...    ...                  ...        ...
# 26797          158.0   112.0     0.0   46.0  2020-04-16 21:46:07        Ibm
# 26795          160.0   160.0     0.0    1.0  2020-04-16 20:57:51        IBM
# 19660          132.0   120.0     0.0   12.0  2020-01-04 09:38:53      Chewy
# 21649           90.0    90.0     0.0    0.0  2020-02-03 09:11:04        SAP
# 14338          380.0   380.0     0.0    0.0  2019-09-10 08:39:33    Netflix
#
#                              level              title           location  \
# entry_id
# 9041                            E7  Software Engineer       New York, NY
# 21423                           E7  Software Engineer        Seattle, WA
# 12694                           69  Software Engineer        Redmond, WA
# 28380                           L8  Software Engineer        Seattle, WA
# 8202        Distinguished Engineer  Software Engineer  Mountain View, CA
# ...                            ...                ...                ...
# 26797                       Senior  Software Engineer         Austin, TX
# 26795                            9  Software Engineer    San Antonio, TX
# 19660                          SE2  Software Engineer         Boston, MA
# 21649                       Intern  Software Engineer  Newport Beach, CA
# 14338     Senior Software Engineer  Software Engineer  San Francisco, CA
#
#           years_experience  years_company                             tag  \
# entry_id
# 9041                   8.0            6.0                      Full Stack
# 21423                 20.0            2.0                         ML / AI
# 12694                 11.0           11.0                         ML / AI
# 28380                 15.0           10.0                         ML / AI
# 8202                  22.0           18.0                        Security
# ...                    ...            ...                             ...
# 26797                  3.0            1.0                      Full Stack
# 26795                  9.0            3.0      API Development (Back-End)
# 19660                  9.0            1.0                      Full Stack
# 21649                  1.0            0.0  Distributed Systems (Back-End)
# 14338                 10.0            3.0     Web Development (Front-End)
#
#           gender       otherdetails
# entry_id
# 9041        Male                NaN
# 21423        NaN                NaN
# 12694     Female                NaN
# 28380       Male                PhD
# 8202        Male                NaN
# ...          ...                ...
# 26797        NaN                NaN
# 26795       Male  25K signing bonus
# 19660       Male                NaN
# 21649       Male            Masters
# 14338        NaN                NaN
#
# [14557 rows x 14 columns]

# %%
comp_normalized.bonus.plot.box()
comp_normalized.sort_values(by='bonus', ascending=False)
# Out:
#           total_comp  salary   stock  bonus            timestamp  \
# entry_id
# 11377         1800.0   350.0   700.0  750.0  2019-07-02 15:05:10
# 12694         2500.0   350.0  1500.0  650.0  2019-07-31 22:52:33
# 10662         1030.0   400.0     0.0  630.0  2019-06-18 17:00:28
# 12829          720.0   200.0    20.0  500.0  2019-08-05 11:16:26
# 17707          680.0   160.0    45.0  475.0  2019-11-16 15:49:12
# ...              ...     ...     ...    ...                  ...
# 20387          195.0   142.0    50.0    0.0  2020-01-17 07:51:56
# 20384           10.0     9.0     0.0    0.0  2020-01-17 07:30:41
# 20380          600.0   210.0   390.0    0.0  2020-01-17 05:48:05
# 20379          225.0   145.0    80.0    0.0  2020-01-17 05:45:25
# 16476          207.0   156.0    51.0    0.0  2019-10-19 10:43:02
#
#                       company              level              title  \
# entry_id
# 11377                Facebook                 E8  Software Engineer
# 12694               Microsoft                 69  Software Engineer
# 10662     Jane Street Capital  Software Engineer  Software Engineer
# 12829                 Argo AI                  5  Software Engineer
# 17707                  Amazon                 L7  Software Engineer
# ...                       ...                ...                ...
# 20387                  Amazon             SDE II  Software Engineer
# 20384                  Andela              ENG 1  Software Engineer
# 20380                    Snap                 L5  Software Engineer
# 20379                  Amazon                 L5  Software Engineer
# 16476                  Amazon                 L5  Software Engineer
#
#                     location  years_experience  years_company  \
# entry_id
# 11377         Menlo Park, CA              31.0           11.0
# 12694            Redmond, WA              11.0           11.0
# 10662           New York, NY               7.0            4.0
# 12829          Princeton, NJ               5.0            1.0
# 17707            Seattle, WA              20.0            0.0
# ...                      ...               ...            ...
# 20387             Boston, MA               3.0            3.0
# 20384     Nairobi, NA, Kenya               3.0            3.5
# 20380            Seattle, WA              15.0            1.0
# 20379             Boston, MA               5.0            2.0
# 16476           New York, NY               2.0            2.0
#
#                                      tag  gender  \
# entry_id
# 11377                           Security    Male
# 12694                            ML / AI  Female
# 10662     Distributed Systems (Back-End)    Male
# 12829                            ML / AI    Male
# 17707                            ML / AI  Female
# ...                                  ...     ...
# 20387                         Full Stack    Male
# 20384         API Development (Back-End)    Male
# 20380                         Full Stack    Male
# 20379         API Development (Back-End)    Male
# 16476                         Full Stack     NaN
#
#                                                otherdetails
# entry_id
# 11377                                                   NaN
# 12694                                                   NaN
# 10662                                                   NaN
# 12829                                    non-tradable stock
# 17707                                               Masters
# ...                                                     ...
# 20387                                                   NaN
# 20384     Salary is actually $9,800 a year but forma val...
# 20380                                                   PhD
# 20379                                               Masters
# 16476                                                   NaN
#
# [14557 rows x 14 columns]

# %%
comp_clean = comp_normalized.drop(columns=['timestamp', 'gender', 'otherdetails', 'title'])
comp_clean.company = comp_clean.company.str.strip()
comp_clean.level = comp_clean.level.str.strip()
comp_clean.location = comp_clean.location.str.strip()
comp_clean.tag = comp_clean.tag.str.strip()

comp_clean.isna().sum(axis=0)
comp_clean
# Out:
# total_comp            0
# salary                0
# stock                 0
# bonus                 0
# company               0
# level                 6
# location              0
# years_experience      0
# years_company         0
# tag                 476
# dtype: int64
#           total_comp  salary  stock  bonus    company  \
# entry_id
# 4              578.0   180.0  387.5    9.0       Uber
# 6              173.0   120.0    0.0   53.0     Amazon
# 10             190.0   110.0   80.0    0.0     Amazon
# 13             156.0   135.0    8.0   13.0  Microsoft
# 16             201.0   157.0   26.0   28.0  Microsoft
# ...              ...     ...    ...    ...        ...
# 30133          115.0   115.0    0.0    0.0        IBM
# 30139          370.0   187.0  150.0   33.0    Twitter
# 30140          212.0   177.0    0.0   35.0  Bloomberg
# 30142          185.0    98.0   57.0   30.0     Google
# 30143          180.0   110.0   55.0   15.0   Broadcom
#
#                              level                    location  \
# entry_id
# 4                           Senior           San Francisco, CA
# 6                               L5       Vancouver, BC, Canada
# 10                              L5                 Seattle, WA
# 13                              62                 Seattle, WA
# 16                              63                 Seattle, WA
# ...                            ...                         ...
# 30133            Advisory Engineer                 Madison, WI
# 30139                   Senior SWE                New York, NY
# 30140     Senior Software Engineer                New York, NY
# 30142                           L4  London, EN, United Kingdom
# 30143                        ICB 3        Tel Aviv, TA, Israel
#
#           years_experience  years_company                             tag
# entry_id
# 4                     10.0            2.0                             NaN
# 6                     11.0            1.0                             NaN
# 10                     3.0            3.0                             NaN
# 13                     4.0            4.0                             NaN
# 16                    12.0            6.0                             NaN
# ...                    ...            ...                             ...
# 30133                  6.0            1.0  Distributed Systems (Back-End)
# 30139                 10.0            6.0                             iOS
# 30140                  2.0            0.0  Distributed Systems (Back-End)
# 30142                  4.0            2.0      API Development (Back-End)
# 30143                  7.0            7.0                      Networking
#
# [14557 rows x 10 columns]

# %%
comp_clean.to_csv('data/clean_comp_data.csv')

# %%
sns.pairplot(comp_clean)
